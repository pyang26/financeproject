# %%
import yfinance as yf

# %%
sp500 = yf.Ticker("^GSPC")

# %%
sp500 = sp500.history(period="max")

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-06-03 00:00:00-04:00  5938.560059  5981.350098  5929.000000  5970.370117
# 2025-06-04 00:00:00-04:00  5978.939941  5990.479980  5966.109863  5970.810059
# 2025-06-05 00:00:00-04:00  5985.669922  5999.700195  5921.200195  5939.299805
# 2025-06-06 00:00:00-04:00  5987.060059  6016.870117  5978.629883  6000.359863
# 2025-06-09 00:00:00-04:00  6004.629883  6020.879883  5994.180176  6019.120117
#
# ...

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2025-05-27 00:00:00-04:00', '2025-05-28 00:00:00-04:00',
#                '2025-05-29 00:00:00-04:00', '2025-05-30 00:00:00-04:00',
#                '2025-06-02 00:00:00-04:00', '2025-06-03 00:00:00-04:00',
#                '2025-06-04 00:00:00-04:00', '2025-06-05 00:00:00-04:00',
#                '2025-06-06 00:00:00-04:00', '2025-06-09 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24475, freq=None)

# %%
sp500.plot.line(y="Close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500["Dividends"]
del sp500["Stock Splits"]

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1)

# %%
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-06-03 00:00:00-04:00  5938.560059  5981.350098  5929.000000  5970.370117
# 2025-06-04 00:00:00-04:00  5978.939941  5990.479980  5966.109863  5970.810059
# 2025-06-05 00:00:00-04:00  5985.669922  5999.700195  5921.200195  5939.299805
# 2025-06-06 00:00:00-04:00  5987.060059  6016.870117  5978.629883  6000.359863
# 2025-06-09 00:00:00-04:00  6004.629883  6020.879883  5994.180176  6019.120117
#
# ...

# %%
sp500 = sp500.loc["1990-01-01":].copy()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2025-06-03 00:00:00-04:00  5938.560059  5981.350098  5929.000000  5970.370117
# 2025-06-04 00:00:00-04:00  5978.939941  5990.479980  5966.109863  5970.810059
# 2025-06-05 00:00:00-04:00  5985.669922  5999.700195  5921.200195  5939.299805
# 2025-06-06 00:00:00-04:00  5987.060059  6016.870117  5978.629883  6000.359863
# 2025-06-09 00:00:00-04:00  6004.629883  6020.879883  5994.180176  6019.120117
#
# ...

# %%
len(sp500)
# Out:
# 8925

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
rfc.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = rfc.predict(test[predictors])

# %%
import pandas as pd 

preds = pd.Series(preds, index=test.index)

# %%
precision_score(test["Target"], preds)
# Out:
# 0.6

# %%
combined = pd.concat([test["Target"], preds], axis=1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
from sklearn.preprocessing import StandardScaler

scaler_X = StandardScaler()
scaler_y = StandardScaler()

train_X = scaler_X.fit_transform(train[predictors])
train_y = scaler_y.fit_transform(train[["Tomorrow"]]).flatten()

test_X = scaler_X.transform(test[predictors])
test_y = scaler_y.transform(test[["Tomorrow"]]).flatten()

# %%
import torch 
import torch.nn as nn
import torch.nn.functional as F
class StockNet(nn.Module):
    def __init__(self, input_size):
        super(StockNet, self).__init__()
        self.fc1 = nn.Linear(input_size, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 1)
        self.relu = nn.LeakyReLU(negative_slope=0.01)
        self.sigmoid = nn.Sigmoid()
    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.fc3(x)
        return x.squeeze(1)

# %%
import numpy as np
import random
import os
def set_seed(seed: int = 42) -> None:
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    # When running on the CuDNN backend, two further options must be set
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    # Set a fixed value for the hash seed
    os.environ["PYTHONHASHSEED"] = str(seed)
    print(f"Random seed set as {seed}")
set_seed(42)
# Out:
# Random seed set as 42

# %%
class StockNetSmall(nn.Module):
    def __init__(self, input_size):
        super(StockNetSmall, self).__init__()
        self.fc1 = nn.Linear(input_size, 144)
        self.fc2 = nn.Linear(144, 72)
        self.fc3 = nn.Linear(72, 36)
        self.fc4 = nn.Linear(36, 18)
        self.fc5 = nn.Linear(18, 1)
        self.relu = nn.LeakyReLU()
        self.sigmoid = nn.Sigmoid()
    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.relu(self.fc3(x))
        x = self.relu(self.fc4(x))
        x = self.fc5(x)
        return x.squeeze(1)

# %%
criterion = nn.MSELoss()

model = StockNet(input_size=len(predictors))
model2 = StockNetSmall(input_size=len(predictors))
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)
optimizer2 = torch.optim.SGD(model2.parameters(), lr=0.1)
def train_model(model, train_X, train_y, criterion, optimizer, epochs=100):
    model.train()
    for epoch in range(epochs):
        inputs = torch.tensor(train_X, dtype=torch.float32)
        targets = torch.tensor(train_y, dtype=torch.float32)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        if epoch % 10 == 0:
            print(f'Epoch {epoch}, Loss: {loss.item()}')

# %%
train_model(model, train_X, train_y, criterion, optimizer, epochs=100)
# Out:
# Epoch 0, Loss: 1.1070688962936401
# Epoch 10, Loss: 0.005469383671879768
# Epoch 20, Loss: 0.002424726029857993
# Epoch 30, Loss: 0.0013035605661571026
# Epoch 40, Loss: 0.0008927253657020628
# Epoch 50, Loss: 0.0007367890793830156
# Epoch 60, Loss: 0.0006722398102283478
# Epoch 70, Loss: 0.0006309593445621431
# Epoch 80, Loss: 0.0006011371733620763
# Epoch 90, Loss: 0.0005777916521765292

# %%
train_model(model2, train_X, train_y, criterion, optimizer2, epochs=100)
# Out:
# Epoch 0, Loss: 1.0099765062332153
# Epoch 10, Loss: 0.20304468274116516
# Epoch 20, Loss: 0.04332330822944641
# Epoch 30, Loss: 0.023489980027079582
# Epoch 40, Loss: 0.013207655400037766
# Epoch 50, Loss: 0.008035203441977501
# Epoch 60, Loss: 0.0061421641148626804
# Epoch 70, Loss: 0.006659053731709719
# Epoch 80, Loss: 0.008222000673413277
# Epoch 90, Loss: 0.00743108568713069

# %%
def backtest(model, test_X, test_y, scaler_y):
    model.eval()
    inputs = torch.tensor(test_X, dtype=torch.float32)
    with torch.no_grad():
        outputs = model(inputs).numpy()
    outputs = scaler_y.inverse_transform(outputs.reshape(-1, 1)).flatten()
    return outputs

# %%
# Get predictions (already normalized)
model.eval()
with torch.no_grad():
    outputs = model(torch.tensor(test_X, dtype=torch.float32)).numpy()
# Inverse transform to get original scale
outputs = scaler_y.inverse_transform(outputs.reshape(-1, 1)).flatten()
# Store in a pandas Series with the test index
outputs_series = pd.Series(outputs, index=test.index)

# %%
model2.eval()
with torch.no_grad():
    outputs2 = model2(torch.tensor(test_X, dtype=torch.float32)).numpy()
outputs2 = scaler_y.inverse_transform(outputs2.reshape(-1, 1)).flatten()
outputs_series2 = pd.Series(outputs2, index=test.index)

comparison2 = pd.DataFrame({
    "Actual": test["Tomorrow"],
    "Predicted": outputs_series2
})
comparison2.plot(title="Model Predictions vs Actual Tomorrow Prices")
# Out:
# <Axes: title={'center': 'Model Predictions vs Actual Tomorrow Prices'}, xlabel='Date'>

# %%
comparison = pd.DataFrame({
    "Actual": test["Tomorrow"],
    "Predicted": outputs_series
})


comparison.plot(title="Actual vs Predicted S&P 500 Close Price (Tomorrow)")
# Out:
# <Axes: title={'center': 'Actual vs Predicted S&P 500 Close Price (Tomorrow)'}, xlabel='Date'>
